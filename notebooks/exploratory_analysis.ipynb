# %%
spikes.to_csv('../Data/detected_cme_spikes.csv', index=False)

# %%
plt.figure(figsize=(14, 5))
plt.plot(df['Datetime'], df['Proton_Density'], label='Proton Density', color='blue')
plt.xlabel('Datetime')
plt.ylabel('Proton Density')
plt.title('Proton Density Over Time')
plt.legend()
plt.grid(True)

# Save graph as image file
plt.savefig('../presentation/cme_spike_graph.png', dpi=300)  # High quality for PPT
plt.show()

# %%
# Spikes ko ek CSV file me save karo
spikes.to_csv('../Data/detected_cme_spikes.csv', index=False)

# %%
# Threshold value define karo (e.g. spike jab > 20 ho)
threshold = 20

# Jo values threshold se zyada hain wo CME spikes hain
spikes = df[df['Proton_Density'] > threshold]

# Spike points dikhao (Datetime + Density)
spikes[['Datetime', 'Proton_Density']]
# Out:
#                Datetime  Proton_Density
# 4   2025-01-01 04:00:00       34.531693
# 12  2025-01-01 12:00:00       35.483925
# 27  2025-01-02 03:00:00       35.751396
# 38  2025-01-02 14:00:00       32.343628
# 43  2025-01-02 19:00:00       34.397793

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 5))  # graph ka size
plt.plot(df['Datetime'], df['Proton_Density'], label='Proton Density', color='blue')
plt.xlabel('Datetime')
plt.ylabel('Proton Density')
plt.title('Proton Density Over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
# DateTime column ko pandas datetime object me convert kar rahe hain
df['Datetime'] = pd.to_datetime(df['Datetime'])

# %%
import pandas as pd

file_path = "../omni_sample_data.csv"   # agar file root folder me hi hai

df = pd.read_csv(file_path)
df.head()
# Out:
#               Datetime  Proton_Density  Plasma_Speed  Proton_Temperature
# 0  2025-01-01 00:00:00        5.993428    311.847992        80076.701850
# 1  2025-01-01 01:00:00        4.723471    416.204198        76481.192999
# 2  2025-01-01 02:00:00        6.295377    380.745886        58769.438869
# 3  2025-01-01 03:00:00        8.046060    366.153900        73690.320159
# 4  2025-01-01 04:00:00       34.531693    430.583814        74859.282252
